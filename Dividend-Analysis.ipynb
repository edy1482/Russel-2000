# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Russel 2000 Dividend Analysis

# %%
df = pd.read_csv("Russell 2000 Stocks List - Characteristics.csv")
df.head()
# Out:
#   Ticker                       Name              Sector     Price  \
# 0   AADI        Aadi Bioscience Inc                 NaN    790.0%
# 1    AAN   Aarons Company Inc (The)         Industrials  1,261.0%
# 2   AAON                  AAON Inc.         Industrials  9,534.0%
# 3    AAT  American Assets Trust Inc         Real Estate  1,808.0%
# 4   ABCB             Ameris Bancorp  Financial Services  3,330.0%
#
#    Dividend Yield 1-Year Dividend Growth 5-Year Dividend Growth (Annualized)  \
# 0        0.000000                    NaN                                 NaN
# 1        0.037135                    NaN                                 NaN
# 2        0.005019                    NaN                                 NaN
# 3        0.073009                   3.1%                                4.1%
# 4        0.017920                   0.0%                                8.4%
#
#   Dividends Per Share (TTM) Market Cap ($M) Trailing P/E Ratio Payout Ratio  \
# ...

# %% [markdown]
# Let's find the best dividends by yield

# %%
df = df.sort_values(by=['Dividend Yield'], ascending = False)
df.head(10)
# Out:
#      Ticker                          Name              Sector     Price  \
# 1695    VIA            Via Renewables Inc                 NaN    945.0%
# 822     IVR  Invesco Mortgage Capital Inc         Real Estate  1,110.0%
# 1164    ORC     Orchid Island Capital Inc         Real Estate    997.0%
# 147     ARR   ARMOUR Residential REIT Inc         Real Estate    509.0%
# 717    HMST                HomeStreet Inc  Financial Services    603.0%
# 1630    TWO   Two Harbors Investment Corp         Real Estate  1,317.0%
# 1309     RC            Ready Capital Corp         Real Estate  1,069.0%
# 119    AOMR   Angel Oak Mortgage REIT Inc                 NaN    774.0%
# 645     GNL          Global Net Lease Inc         Real Estate    951.0%
# 1124   NYMT   New York Mortgage Trust Inc         Real Estate    965.0%
#
#       Dividend Yield 1-Year Dividend Growth  \
# 1695        0.275517                   0.0%
# 822         0.216352                 344.4%
# ...

# %% [markdown]
# A lot of these are real estate companies - I want to avoid sector risk so lets find out the highest dividend yield by sector
